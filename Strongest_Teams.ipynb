# %% [markdown]
# ### Using the stationary distribution of an MDP to find teams' strength

# %%
# Import libraries
import numpy as np
import pandas as pd
import math

# %%
'''
Calculates the stationary distribution of M using eigenvectors

Args:
    M: the MDP transistion matrix
    
Returns:
    vec: the first eigenvector found
'''
def getStationaryDist(M):
    w,v = np.linalg.eig(M.transpose())
    
    for i in range(0,len(w)):
        if w[i] - 1 < 1e-8 and w[i]-1 > -1e-8:
            vec = v[:,i]
            sumProb = 0
            for j in range(0,len(vec)):
                sumProb += vec[j]
            vec = vec/sumProb
            return vec.astype(float)
            

# Testing getStationaryDist

M = np.zeros((3,3))
M[0][0] = 0.7
M[0][1] = 0.2
M[0][2] = 0.1
M[1][0] = 0.4
M[1][1] = 0.6
M[1][2] = 0.0
M[2][0] = 0.0
M[2][1] = 1.0
M[2][2] = 0.0
M2 = np.zeros((2,2))
M2[0][0] = 0.3
M2[0][1] = 0.7
M2[1][0] = 0.8
M2[1][1] = 0.2
getStationaryDist(M)
# Out:
# C:\Users\Kareem Elsawah\Anaconda3\envs\pytorch\lib\site-packages\ipykernel_launcher.py:20: ComplexWarning: Casting complex values to real discards the imaginary part
# array([0.54054054, 0.40540541, 0.05405405])

# %%
all_data = pd.read_csv("results.csv")
training_data = all_data.iloc[25000:,:5]
minYear = int(training_data.iloc[0].date.split("-")[0])

'''
Converts a date to an integer

Args:
    date: a date in the form "YYYY-MM-DD"
    
Returns:
    finalDate: an equivalent int to represent the date
    
'''
def preprocessDate(date):
    arr = np.array(date.split("-"))
    arr = arr.astype(int)
    yearDiff = arr[0]-minYear
    finalDate = yearDiff*365+arr[1]*30+arr[2]
    return finalDate

training_data.date = training_data.date.apply(preprocessDate)
maxDate = 6060
print("Number of games: {}".format(training_data.shape[0]))
training_data.head(3)
# Out:
# Number of games: 14669
#        date       home_team   away_team  home_score  away_score
# 25000   350  Czech Republic      Sweden           3           3
# 25001   350         Denmark      Poland           2           0
# 25002   350         Ecuador  Costa Rica           2           2

# %%
teams = training_data.home_team
teams = teams.append(training_data.away_team)
teams = teams.unique()
teams = teams.tolist()
S = len(teams)
print("Numer of unique teams: {}".format(S))
# Out:
# Numer of unique teams: 282

# %%
M = np.zeros((S,S))
dateParam = -1*0.0075

'''
Adds a game to the transition matrix M

Args:
    homeIndex: unique index of the home team
    awayIndex: unique index of the away team
    home_score: number of goals of the home team
    away_score: number of goals of the home team
    date: date converted to an integer

Returns:
    None
'''
def modifyMatrix(homeIndex,awayIndex,home_score,away_score,date):
    toAdd = 0
    dateFactor = math.exp(dateParam*float(date-maxDate))
    
    if home_score < away_score:
        M[awayIndex][awayIndex] += 1*dateFactor
        M[homeIndex][awayIndex] += 1*dateFactor
        toAdd += away_score
    elif home_score > away_score:
        M[homeIndex][homeIndex] += 1*dateFactor
        M[awayIndex][homeIndex] += 1*dateFactor
        toAdd += home_score
    if home_score+away_score > 0:
        toAdd = float(toAdd)/(home_score+away_score)
        M[awayIndex][awayIndex] += toAdd*dateFactor
        M[homeIndex][awayIndex] += toAdd*dateFactor
        M[homeIndex][homeIndex] += toAdd*dateFactor
        M[awayIndex][homeIndex] += toAdd*dateFactor

# Add games to the trasition matrix
training_data_len = len(training_data)
for i in range(5000,training_data_len):
    date = training_data.iloc[i].date
    home = training_data.iloc[i].home_team
    away = training_data.iloc[i].away_team
    home_score = training_data.iloc[i].home_score
    away_score = training_data.iloc[i].away_score
    homeIndex = teams.index(home)
    awayIndex = teams.index(away)
    modifyMatrix(homeIndex,awayIndex,home_score,away_score,date)
    
'''
Normalize the given matrix M

Args:
    M: transition matrix

Returns:
    M: normalized transition matrix
'''
def normalizeTransitionMatrix(M):
    for i in range(0,M.shape[0]):
        row = M[i]
        rowSum = np.sum(row)
        if rowSum > 0:
            row /= rowSum
        M[i] = row
    return M
M2 = normalizeTransitionMatrix(M)
stationaryDist = getStationaryDist(M2)
# Out:
# C:\Users\Kareem Elsawah\Anaconda3\envs\pytorch\lib\site-packages\ipykernel_launcher.py:20: ComplexWarning: Casting complex values to real discards the imaginary part

# %%
# Sort the final score and display the teams in the order of the strongest to the weakest

sortedDist = np.sort(stationaryDist)
sortedDist = np.flip(sortedDist,axis=0)
toSearch = stationaryDist.tolist()
countryNames = np.chararray(len(teams))
for i in range(0,len(sortedDist)):
    countryIndex = toSearch.index(sortedDist[i])
    countryName = teams[countryIndex]
    print(str(i+1)+": "+countryName)
# Out:
# 1: Spain
# 2: Germany
# 3: Russia
# 4: Netherlands
# 5: Iran
# 6: England
# 7: Trinidad and Tobago
# 8: USA
# 9: Chile
# 10: Turkey
# 11: Croatia
# 12: Mexico
# 13: Saudi Arabia
# 14: Japan
# 15: Qatar
# 16: Honduras
# 17: Portugal
# 18: France
# 19: Uruguay
# 20: Switzerland
# 21: Costa Rica
# 22: Sweden
# 23: Italy
# 24: Nigeria
# 25: Bahrain
# 26: Australia
# 27: Ukraine
# 28: Jamaica
# 29: Venezuela
# 30: Brazil
# 31: Poland
# 32: Czech Republic
# 33: Paraguay
# 34: El Salvador
# 35: Cuba
# 36: Libya
# 37: Guatemala
# 38: Argentina
# 39: Oman
# 40: Lithuania
# 41: Syria
# 42: Korea DPR
# 43: Korea Republic
# 44: India
# 45: Greece
# 46: Wales
# 47: Algeria
# 48: Bolivia
# 49: Uzbekistan
# 50: Panama
# 51: Romania
# 52: Bermuda
# 53: Bosnia-Herzegovina
# 54: Serbia
# 55: Padania
# 56: Iraq
# 57: Peru
# 58: China
# 59: Grenada
# 60: Ghana
# 61: Austria
# 62: Gabon
# 63: Colombia
# 64: Ecuador
# 65: Thailand
# 66: Haiti
# 67: South Africa
# 68: Malawi
# 69: Jordan
# 70: Latvia
# 71: Kuwait
# 72: Barbados
# 73: Estonia
# 74: Ivory Coast
# 75: Egypt
# 76: Guadeloupe
# 77: Maldives
# 78: United Arab Emirates
# 79: Burkina Faso
# 80: Antigua and Barbuda
# 81: Mozambique
# 82: Suriname
# 83: Azerbaijan
# 84: Ireland
# 85: Cameroon
# 86: Mali
# 87: Burma
# 88: Kenya
# 89: Singapore
# 90: Finland
# 91: Slovakia
# 92: Guinea
# 93: Belgium
# 94: Namibia
# 95: Morocco
# 96: Sudan
# 97: Uganda
# 98: Kazakhstan
# 99: Sierra Leone
# 100: Benin
# 101: Equatorial Guinea
# 102: Montenegro
# 103: Rwanda
# 104: Denmark
# 105: Zambia
# 106: Senegal
# 107: Congo DR
# 108: Curaçao
# 109: Tunisia
# 110: Martinique
# 111: Nepal
# 112: Slovenia
# 113: Congo
# 114: Cape Verde
# 115: Lesotho
# 116: Gambia
# 117: Georgia
# 118: Arameans Suryoye
# 119: Turkmenistan
# 120: Indonesia
# 121: Lebanon
# 122: Andorra
# 123: Burundi
# 124: Iceland
# 125: Angola
# 126: Canada
# 127: Liechtenstein
# 128: Macedonia
# 129: Guyana
# 130: Zimbabwe
# 131: Albania
# 132: Belarus
# 133: Chad
# 134: Botswana
# 135: Togo
# 136: Sápmi
# 137: Malta
# 138: Tanzania
# 139: New Caledonia
# 140: Sri Lanka
# 141: Scotland
# 142: Cyprus
# 143: Armenia
# 144: Hungary
# 145: Seychelles
# 146: Niger
# 147: Tajikistan
# 148: Bulgaria
# 149: Norway
# 150: Swaziland
# 151: Réunion
# 152: Faroe Islands
# 153: Madagascar
# 154: Jersey
# 155: Belize
# 156: Liberia
# 157: Luxembourg
# 158: Israel
# 159: New Zealand
# 160: Malaysia
# 161: Mauritius
# 162: Cambodia
# 163: Ethiopia
# 164: Vietnam
# 165: Bahamas
# 166: Djibouti
# 167: Provence
# 168: Vanuatu
# 169: Iraqi Kurdistan
# 170: Northern Ireland
# 171: Moldova
# 172: French Guyana
# 173: Cayman Islands
# 174: Mauritania
# 175: St. Kitts and Nevis
# 176: Hong Kong
# 177: Pakistan
# 178: San Marino
# 179: Palestine
# 180: Bhutan
# 181: Fiji
# 182: Afghanistan
# 183: Puerto Rico
# 184: St. Vincent and the Grenadines
# 185: St. Lucia
# 186: Tahiti
# 187: Yemen
# 188: St. Martin
# 189: Comoros
# 190: Laos
# 191: Macau
# 192: Bangladesh
# 193: Nicaragua
# 194: Gibraltar
# 195: Somalia
# 196: Mayotte
# 197: Rhodes
# 198: Philippines
# 199: Guersney
# 200: Dominica
# 201: Dominican Republic
# 202: Aruba
# 203: Åland Islands
# 204: Zanzibar
# 205: Ynys Môn
# 206: Isle of Man
# 207: British Virgin Islands
# 208: Isle of Wight
# 209: Anguilla
# 210: Brunei
# 211: Saare County
# 212: Menorca
# 213: Frøya
# 214: Solomon Islands
# 215: Western Isles
# 216: Mongolia
# 217: Greenland
# 218: Guernsey
# 219: East Timor
# 220: Guam
# 221: Gotland
# 222: Occitania
# 223: Shetland
# 224: Kyrgyzstan
# 225: Falkland Islands
# 226: Gozo
# 227: Northern Mariana Islands
# 228: Eritrea
# 229: Cook Islands
# 230: Two Sicilies
# 231: Tonga
# 232: Guinea-Bissau
# 233: Central African Republic
# 234: St. Pierre & Miquelon
# 235: Montserrat
# 236: Taiwan
# 237: Virgin Islands
# 238: Bonaire
# 239: Alderney
# 240: Tuvalu
# 241: Samoa
# 242: Papua New Guinea
# 243: American Samoa
# 244: Turks and Caicos Islands
# 245: Kiribati
# 246: São Tomé and Príncipe
# 247: Western Sahara
# 248: Northern Cyprus
# 249: Tamil Eelam
# 250: Raetia
# 251: Darfur
# 252: South Sudan
# 253: Ellan Vannin
# 254: County of Nice
# 255: Artsakh
# 256: Kosovo
# 257: South Ossetia
# 258: Abkhazia
# 259: Felvidék
# 260: Romani people
# 261: Hitra
# 262: Székely Land
# 263: Panjab
# 264: Somaliland
# 265: Sint Maarten
# 266: Western Armenia
# 267: United Koreans in Japan
# 268: Chagos Islands
# 269: Orkney
# 270: Kárpátalja
# 271: Barawa
# 272: Cascadia
# 273: Matabeleland
# 274: Kabylia
# 275: Tibet
# 276: Sark
# 277: Sark
# 278: Sark
# 279: Sark
# 280: Sark
# 281: Vatican
# 282: Monaco

# %% [markdown]
# Just looking at the teams, you can clearly see that the order is not random and there is a measure of strength.
